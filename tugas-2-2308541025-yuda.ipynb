# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
nama_pelari = "Kuartet lalu muhamad zohri"
nama_cabang = "lari estafet 4x100 putra"
rekan_tim = "Bayu kartanegara,Wahyu setiawan,dan Sudirman hadi"
print (nama_pelari + 'menjadi pelari terakhir' +'di lari estafet 4x100 putra'+ nama_cabang +'bersama'+rekan_tim)
# Out:
# Kuartet lalu muhamad zohrimenjadi pelari terakhirdi lari estafet 4x100 putralari estafet 4x100 putrabersamaBayu kartanegara,Wahyu setiawan,dan Sudirman hadi

# %%
print ('bermain dengan angka')
kata = input ('masukan kata yang ingin dicoba (minimaL 5 angka)')
print (len('bermain dengan angka'))
print (angka[:])
print (angka[1:3])
print (angka[0:5:2])
print (angka[2:-1:3])
print ('semoga memahami')
# Out:
# bermain dengan angka

# %%
kendaraan_motor = 'honda CB500X adalah motor buatan jepang'
print (kendaraan_motor[0:7])
print (kendaraan_motor[0:-5])
print (kendaraan_motor[9:3])
print (kendaraan_motor[6:-1])
print (kendaraan_motor[5:-4:3])
print (kendaraan_motor[:1])
print (kendaraan_motor[8:])
print (kendaraan_motor[:])
# Out:
# honda C
# honda CB500X adalah motor buatan j
#
# CB500X adalah motor buatan jepan
#  5Xdamobt
# h
# 500X adalah motor buatan jepang
# honda CB500X adalah motor buatan jepang

# %%
jumlah_buku_dibagi_jumlah_siswa = 38/19
print (jumlah_buku_dibagi_jumlah_siswa)
jumlah_bangku_dibagi_jumlah_siswa = 76/19
print (jumlah_bangku_dibagi_jumlah_siswa)
jumlah_kertas_dibagi_jumlah_siswa = 19/19
print (jumlah_kertas_dibagi_jumlah_siswa)
total = 38/19 +  76/19 + 19/19
print (total)
# Out:
# 2.0
# 4.0
# 1.0
# 7.0

# %%
semangka_anggur = 6 < 9
print (semangka_anggur)
melon_durian = 5 > 3
print (melon_durian)
nanas_klengkeng = 6 < 10
print (nanas_klengkeng)
langsat_mengkudu = 12 > 6
print (langsat_mengkudu)
# Out:
# True
# True
# True
# True

# %%
gelang = 30
kalung = 45
print(gelang > 25 and kalung < 50)
print(gelang < 25 or kalung < 50)
print(gelang < 25 or kalung > 45)
print(not gelang < 25 or kalung > 50)
# Out:
# True
# True
# False
# True
