# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
angka_25= range (100,10000,1000)
print(angka)
for isi in angka :
    print(isi)
# Out:
# range(100, 10000, 1000)
# 100
# 1100
# 2100
# 3100
# 4100
# 5100
# 6100
# 7100
# 8100
# 9100

# %%
data_25= [10,20,30,100,90,80,-10,-20,-30]
terbesar = data [0]
data_terurut = sorted(data)
print(data_terurut)
# Out:
# [-30, -20, -10, 10, 20, 30, 80, 90, 100]

# %%
for i in range(len(data_25)):
    if data[i] > terbesar:
        terbesar = data[i]
print(terbesar)
# Out:
# 100

# %%
nilai_positif_25 = []
for angka in data :
    if angka > 0:
        nilai_positif.append(angka)
print("nilai_positif:", nilai_positif) 

nilai_negatif = []
for angka in data :
    if angka < 0:
        nilai_negatif.append(angka)
print("nilai_negatif:", nilai_negatif)
# Out:
# nilai_positif: [10, 20, 30, 100, 90, 80, 10, 20, 30, 100, 90, 80]
# nilai_negatif: [-10, -20, -30]

# %%
matriks_25= [
    [7,23,13,22],
    [23,52,87,70],
    [10,12,25,31],
    [15,55,68,20]
]
print(matriks)
# Out:
# [[7, 23, 13, 22], [23, 52, 87, 70], [10, 12, 25, 31], [15, 55, 68, 20]]

# %%
matriks_25[3][2]
# Out:
# 68

# %%
matriks_25[2][3]=25
print(matriks[2][3])
# Out:
# 25

# %%
matriks_25
# Out:
# [[7, 23, 13, 22], [23, 52, 87, 70], [10, 12, 25, 25], [15, 55, 68, 20]]

# %%
for kolom in matriks_25:
    print(kolom)
    for baris in kolom:
        print(baris)
# Out:
# [7, 23, 13, 22]
# 7
# 23
# 13
# 22
# [23, 52, 87, 70]
# 23
# 52
# 87
# 70
# [10, 12, 25, 25]
# 10
# 12
# 25
# 25
# [15, 55, 68, 20]
# 15
# 55
# 68
# 20

# %%
nama = ('yuda','nodi','ijat','yogi')

# %%
print(nama[0])
# Out:
# yuda

# %%
print(nama[1:3])
# Out:
# ('nodi', 'ijat')

# %%
for isi in nama [0:4]:
    print(isi)
# Out:
# yuda
# nodi
# ijat
# yogi

# %%
nama.count("nodi")
# Out:
# 1

# %%
nama.index("ijat")
# Out:
# 2

# %%
angka_25 = {
    "0" : "nol"
    "1" : "satu"
    "2" : "dua"
    "3" : "tiga"
    "4" : "empat"
    "5" : "lima"
    "6" : "enam"
    "7" : "tujuh"
    "8" : "delapan"
    "9" : "sembilan"
}

# %%
nomor_HP = input ("masukkan nomor HP anda")
nomor_angka = ""
for isi in nomor_HP :
    nomor_angka += angka.get(isi) + ""
    print(nomor_angka)
# Out:
# masukkan nomor HP anda 0882190098916
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 4
#       2 nomor_angka = ""
#       3 for isi in nomor_HP :
# ----> 4     nomor_angka += angka.get(isi) + ""
#       5     print(nomor_angka)
#
# AttributeError: 'int' object has no attribute 'get'

# %%
def nama_roti_25(merk_roti_25):
    print("nama rotinya adalah {merk_roti_25}")
merk_roti_25 = input("merk rotinya adalah") 
def nama_roti_25 (merk_roti_25):
    print("nama rotinya adalah{merk_roti_25}")
merk_roti_25 = input("merk rotinya adalah")
# Out:
# merk rotinya adalah AOKA
# merk rotinya adalah AOKA
